# %% [markdown]
# 🔹 STEP 0: Mount Google Drive & Imports

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
# Out:
# Mounted at /content/drive

# %% [markdown]
# 🔹 STEP 1: Define Dataset Paths

# %%
BASE_PATH = "/content/drive/MyDrive/OEL/PH2Dataset/PH2 Dataset images"
MASK_SAVE_PATH = "/content/drive/MyDrive/OEL/PH2Dataset/generated_masks"
LABEL_TXT = "/content/drive/MyDrive/OEL/PH2Dataset/PH2_dataset.txt"

os.makedirs(MASK_SAVE_PATH, exist_ok=True)

# %% [markdown]
# 🔹 STEP 2: Image Pre-Processing Functions
# ✅ 1. Image Enhancement (CLAHE)

# %%
def enhance_image(img):
    lab = cv2.cvtColor(img, cv2.COLOR_BGR2LAB)
    l, a, b = cv2.split(lab)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    l = clahe.apply(l)
    merged = cv2.merge((l, a, b))
    return cv2.cvtColor(merged, cv2.COLOR_LAB2BGR)

# %% [markdown]
# ✅ 2. Hair Removal (Black-Hat + Inpainting)

# %%
def remove_hairs(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (17,17))
    blackhat = cv2.morphologyEx(gray, cv2.MORPH_BLACKHAT, kernel)
    _, mask = cv2.threshold(blackhat, 10, 255, cv2.THRESH_BINARY)
    return cv2.inpaint(img, mask, 1, cv2.INPAINT_TELEA)

# %% [markdown]
# 🔹 STEP 3: Lesion Segmentation

# %%
def segment_lesion(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    blur = cv2.GaussianBlur(gray, (5,5), 0)

    _, binary = cv2.threshold(
        blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU
    )

    kernel = np.ones((5,5), np.uint8)

    # Morphological Operations
    binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
    binary = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)
    binary = cv2.morphologyEx(binary, cv2.MORPH_ERODE, kernel, iterations=1)

    return binary

# %% [markdown]
# 🔹 STEP 4: Generate Masks + Segmentation Evaluation

# %%
y_true_all, y_pred_all = [], []

for folder in tqdm(os.listdir(BASE_PATH)):
    folder_path = os.path.join(BASE_PATH, folder)
    if not os.path.isdir(folder_path):
        continue

    img_path = os.path.join(folder_path, f"{folder}_Dermoscopic_Image")
    gt_path  = os.path.join(folder_path, f"{folder}_lesion")

    if not os.path.exists(img_path) or not os.path.exists(gt_path):
        continue

    img = cv2.imread(os.path.join(img_path, os.listdir(img_path)[0]))
    gt  = cv2.imread(os.path.join(gt_path, os.listdir(gt_path)[0]), 0)

    if img is None or gt is None:
        continue

    img = enhance_image(img)
    img = remove_hairs(img)
    pred_mask = segment_lesion(img)

    cv2.imwrite(
        os.path.join(MASK_SAVE_PATH, f"{folder}_mask.png"),
        pred_mask
    )

    y_true_all.extend((gt > 0).flatten())
    y_pred_all.extend((pred_mask > 0).flatten())
# Out:
# 100%|██████████| 200/200 [07:24<00:00,  2.22s/it]

# %% [markdown]
# 🔹 Segmentation Metrics

# %%
cm = confusion_matrix(y_true_all, y_pred_all)
TN, FP, FN, TP = cm.ravel()

accuracy = (TP + TN) / (TP + TN + FP + FN)
sensitivity = TP / (TP + FN)
specificity = TN / (TN + FP)

print("Confusion Matrix:\n", cm)
print(f"Accuracy     : {accuracy:.4f}")
print(f"Sensitivity  : {sensitivity:.4f}")
print(f"Specificity  : {specificity:.4f}")
# Out:
# Confusion Matrix:
#  [[51276641  8451041]
#  [13095887 15339754]]
# Accuracy     : 0.7556
# Sensitivity  : 0.5395
# Specificity  : 0.8585

# %% [markdown]
# STEP 5: Load Labels from .txt File

# %%
label_dict = {}

with open(LABEL_TXT, "r") as f:
    for line in f:
        if line.strip() == "" or line.startswith("Name") or line.startswith("Legends for Clinical Diagnosis:"):
            continue

        parts = [p.strip() for p in line.split("||") if p.strip()]

        # Ensure there are enough parts to extract image ID and clinical diagnosis
        if len(parts) < 2:
            continue

        img_id = parts[0]
        clinical_diagnosis = parts[1]

        if "Melanoma" in clinical_diagnosis:
            label_dict[img_id] = 1  # Melanoma
        else:
            # Treat all other valid diagnoses as Common Nevus (or benign) if not Melanoma
            label_dict[img_id] = 0  # Common Nevus or other benign lesion
            # Note: This assumes that if it's not Melanoma, it's the 'other' class we want to detect against.
            # For a binary classification of "Melanoma" vs "Non-Melanoma" (including Common Nevus), this approach is suitable.

print("Total labels loaded:", len(label_dict))
# Out:
# Total labels loaded: 201

# %%
import os

project_path = '/content/drive/MyDrive/OEL'

if os.path.exists(project_path):
    print(f"Contents of {project_path}:")
    for root, dirs, files in os.walk(project_path):
        level = root.replace(project_path, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print(f'{indent}{os.path.basename(root)}/')
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print(f'{subindent}{f}')
else:
    print(f"Path does not exist: {project_path}")
# Out:
# Contents of /content/drive/MyDrive/OEL:
# OEL/
#     PH2Dataset/
#         PH2_dataset.txt
#         Readme.txt
#         PH2_dataset.xlsx
#         PH2 Dataset images/
#             IMD009/
#                 IMD009_Dermoscopic_Image/
#                     IMD009.bmp
#                 IMD009_lesion/
#                     IMD009_lesion.bmp
#             IMD004/
#                 IMD004_lesion/
#                     IMD004_lesion.bmp
#                 IMD004_Dermoscopic_Image/
#                     IMD004.bmp
#                 IMD004_roi/
#                     IMD004_R1_Label4.bmp
#                     IMD004_R2_Label3.bmp
#             IMD002/
#                 IMD002_Dermoscopic_Image/
#                     IMD002.bmp
#                 IMD002_roi/
#                     IMD002_R2_Label3.bmp
#                     IMD002_R1_Label4.bmp
#                 IMD002_lesion/
#                     IMD002_lesion.bmp
#             IMD015/
#                 IMD015_Dermoscopic_Image/
#                     IMD015.bmp
#                 IMD015_lesion/
#                     IMD015_lesion.bmp
#             IMD010/
#                 IMD010_lesion/
#                     IMD010_lesion.bmp
#                 IMD010_Dermoscopic_Image/
#                     IMD010.bmp
#             IMD006/
#                 IMD006_lesion/
#                     IMD006_lesion.bmp
#                 IMD006_Dermoscopic_Image/
#                     IMD006.bmp
#             IMD003/
#                 IMD003_roi/
#                     IMD003_R1_Label4.bmp
#                 IMD003_lesion/
#                     IMD003_lesion.bmp
#                 IMD003_Dermoscopic_Image/
#                     IMD003.bmp
#             IMD013/
#                 IMD013_Dermoscopic_Image/
#                     IMD013.bmp
#                 IMD013_lesion/
#                     IMD013_lesion.bmp
#                 IMD013_roi/
#                     IMD013_R2_Label3.bmp
#                     IMD013_R1_Label4.bmp
#             IMD008/
#                 IMD008_Dermoscopic_Image/
#                     IMD008.bmp
#                 IMD008_lesion/
#                     IMD008_lesion.bmp
#             IMD014/
#                 IMD014_roi/
#                     IMD014_R2_Label3.bmp
#                     IMD014_R1_Label3.bmp
#                 IMD014_lesion/
#                     IMD014_lesion.bmp
#                 IMD014_Dermoscopic_Image/
#                     IMD014.bmp
#             IMD018/
#                 IMD018_lesion/
#                     IMD018_lesion.bmp
#                 IMD018_Dermoscopic_Image/
#                     IMD018.bmp
#             IMD020/
#                 IMD020_Dermoscopic_Image/
#                     IMD020.bmp
#                 IMD020_lesion/
#                     IMD020_lesion.bmp
#                 IMD020_roi/
#                     IMD020_R1_Label4.bmp
#             IMD019/
#                 IMD019_Dermoscopic_Image/
#                     IMD019.bmp
#                 IMD019_lesion/
#                     IMD019_lesion.bmp
#             IMD017/
#                 IMD017_lesion/
#                     IMD017_lesion.bmp
#                 IMD017_Dermoscopic_Image/
#                     IMD017.bmp
#                 IMD017_roi/
#                     IMD017_R2_Label3.bmp
#                     IMD017_R1_Label4.bmp
#             IMD025/
#                 IMD025_roi/
#                     IMD025_R1_Label3.bmp
#                 IMD025_Dermoscopic_Image/
#                     IMD025.bmp
#                 IMD025_lesion/
#                     IMD025_lesion.bmp
#             IMD023/
#                 IMD023_lesion/
#                     IMD023_lesion.bmp
#                 IMD023_Dermoscopic_Image/
#                     IMD023.bmp
#             IMD022/
#                 IMD022_Dermoscopic_Image/
#                     IMD022.bmp
#                 IMD022_lesion/
#                     IMD022_lesion.bmp
#                 IMD022_roi/
#                     IMD022_R1_Label3.bmp
#             IMD021/
#                 IMD021_Dermoscopic_Image/
#                     IMD021.bmp
#                 IMD021_lesion/
#                     IMD021_lesion.bmp
#             IMD024/
#                 IMD024_Dermoscopic_Image/
#                     IMD024.bmp
#                 IMD024_lesion/
#                     IMD024_lesion.bmp
#                 IMD024_roi/
#                     IMD024_R1_Label4.bmp
#                     IMD024_R2_Label3.bmp
#             IMD016/
#                 IMD016_Dermoscopic_Image/
#                     IMD016.bmp
#                 IMD016_lesion/
#                     IMD016_lesion.bmp
#             IMD027/
#                 IMD027_lesion/
#                     IMD027_lesion.bmp
#                 IMD027_Dermoscopic_Image/
#                     IMD027.bmp
#             IMD030/
#                 IMD030_Dermoscopic_Image/
#                     IMD030.bmp
#                 IMD030_roi/
#                     IMD030_R2_Label3.bmp
#                     IMD030_R1_Label4.bmp
#                 IMD030_lesion/
#                     IMD030_lesion.bmp
#             IMD032/
#                 IMD032_Dermoscopic_Image/
#                     IMD032.bmp
#                 IMD032_lesion/
#                     IMD032_lesion.bmp
#             IMD039/
#                 IMD039_Dermoscopic_Image/
#                     IMD039.bmp
#                 IMD039_lesion/
#                     IMD039_lesion.bmp
#             IMD038/
#                 IMD038_Dermoscopic_Image/
#                     IMD038.bmp
#                 IMD038_roi/
#                     IMD038_R1_Label4.bmp
#                 IMD038_lesion/
#                     IMD038_lesion.bmp
#             IMD031/
#                 IMD031_roi/
#                     IMD031_R1_Label5.bmp
#                     IMD031_R2_Label4.bmp
#                 IMD031_lesion/
#                     IMD031_lesion.bmp
#                 IMD031_Dermoscopic_Image/
#                     IMD031.bmp
#             IMD037/
#                 IMD037_Dermoscopic_Image/
#                     IMD037.bmp
#                 IMD037_lesion/
#                     IMD037_lesion.bmp
#             IMD036/
#                 IMD036_lesion/
#                     IMD036_lesion.bmp
#                 IMD036_Dermoscopic_Image/
#                     IMD036.bmp
#                 IMD036_roi/
#                     IMD036_R1_Label3.bmp
#             IMD033/
#                 IMD033_lesion/
#                     IMD033_lesion.bmp
#                 IMD033_Dermoscopic_Image/
#                     IMD033.bmp
#                 IMD033_roi/
#                     IMD033_R2_Label6.bmp
#                     IMD033_R1_Label6.bmp
#                     IMD033_R3_Label3.bmp
#             IMD035/
#                 IMD035_Dermoscopic_Image/
#                     IMD035.bmp
#                 IMD035_lesion/
#                     IMD035_lesion.bmp
#             IMD041/
#                 IMD041_Dermoscopic_Image/
#                     IMD041.bmp
#                 IMD041_lesion/
#                     IMD041_lesion.bmp
#             IMD040/
#                 IMD040_Dermoscopic_Image/
#                     IMD040.bmp
#                 IMD040_lesion/
#                     IMD040_lesion.bmp
#             IMD045/
#                 IMD045_Dermoscopic_Image/
#                     IMD045.bmp
#                 IMD045_lesion/
#                     IMD045_lesion.bmp
#             IMD047/
#                 IMD047_Dermoscopic_Image/
#                     IMD047.bmp
#                 IMD047_lesion/
#                     IMD047_lesion.bmp
#             IMD043/
#                 IMD043_lesion/
#                     IMD043_lesion.bmp
#                 IMD043_Dermoscopic_Image/
#                     IMD043.bmp
#             IMD044/
#                 IMD044_Dermoscopic_Image/
#                     IMD044.bmp
#                 IMD044_lesion/
#                     IMD044_lesion.bmp
#             IMD049/
#                 IMD049_lesion/
#                     IMD049_lesion.bmp
#                 IMD049_Dermoscopic_Image/
#                     IMD049.bmp
#             IMD048/
#                 IMD048_Dermoscopic_Image/
#                     IMD048.bmp
#                 IMD048_lesion/
#                     IMD048_lesion.bmp
#             IMD042/
#                 IMD042_Dermoscopic_Image/
#                     IMD042.bmp
#                 IMD042_lesion/
#                     IMD042_lesion.bmp
#             IMD050/
#                 IMD050_lesion/
#                     IMD050_lesion.bmp
#                 IMD050_Dermoscopic_Image/
#                     IMD050.bmp
#             IMD057/
#                 IMD057_Dermoscopic_Image/
#                     IMD057.bmp
#                 IMD057_roi/
#                     IMD057_R2_Label.bmp
#                     IMD057_R1_Label4.bmp
#                 IMD057_lesion/
#                     IMD057_lesion.bmp
#             IMD078/
#                 IMD078_Dermoscopic_Image/
#                     IMD078.bmp
#                 IMD078_lesion/
#                     IMD078_lesion.bmp
#                 IMD078_roi/
#                     IMD078_R1_Label6.bmp
#             IMD063/
#                 IMD063_lesion/
#                     IMD063_lesion.bmp
#                 IMD063_Dermoscopic_Image/
#                     IMD063.bmp
#             IMD058/
#                 IMD058_lesion/
#                     IMD058_lesion.bmp
#                 IMD058_roi/
#                     IMD058_R2_Label5.bmp
#                     IMD058_R1_Label1.bmp
#                     IMD058_R3_Label4.bmp
#                 IMD058_Dermoscopic_Image/
#                     IMD058.bmp
#             IMD076/
#                 IMD076_lesion/
#                     IMD076_lesion.bmp
#                 IMD076_Dermoscopic_Image/
#                     IMD076.bmp
#             IMD065/
#                 IMD065_lesion/
#                     IMD065_lesion.bmp
#                 IMD065_Dermoscopic_Image/
#                     IMD065.bmp
#             IMD061/
#                 IMD061_Dermoscopic_Image/
#                     IMD061.bmp
#                 IMD061_lesion/
#                     IMD061_lesion.bmp
#             IMD064/
#                 IMD064_Dermoscopic_Image/
#                     IMD064.bmp
#                 IMD064_lesion/
#                     IMD064_lesion.bmp
#             IMD075/
#                 IMD075_Dermoscopic_Image/
#                     IMD075.bmp
#                 IMD075_lesion/
#                     IMD075_lesion.bmp
#             IMD080/
#                 IMD080_Dermoscopic_Image/
#                     IMD080.bmp
#                 IMD080_lesion/
#                     IMD080_lesion.bmp
#             IMD085/
#                 IMD085_Dermoscopic_Image/
#                     IMD085.bmp
#                 IMD085_lesion/
#                     IMD085_lesion.bmp
#             IMD090/
#                 IMD090_Dermoscopic_Image/
#                     IMD090.bmp
#                 IMD090_roi/
#                     IMD090_R2_Label5.bmp
#                     IMD090_R3_Label1.bmp
#                     IMD090_R1_Label6.bmp
#                 IMD090_lesion/
#                     IMD090_lesion.bmp
#             IMD105/
#                 IMD105_lesion/
#                     IMD105_lesion.bmp
#                 IMD105_Dermoscopic_Image/
#                     IMD105.bmp
#             IMD091/
#                 IMD091_Dermoscopic_Image/
#                     IMD091.bmp
#                 IMD091_lesion/
#                     IMD091_lesion.bmp
#             IMD088/
#                 IMD088_Dermoscopic_Image/
#                     IMD088.bmp
#                 IMD088_lesion/
#                     IMD088_lesion.bmp
#                 IMD088_roi/
#                     IMD088_R1_Label5.bmp
#                     IMD088_R2_Label4.bmp
#             IMD092/
#                 IMD092_Dermoscopic_Image/
#                     IMD092.bmp
#                 IMD092_lesion/
#                     IMD092_lesion.bmp
#             IMD108/
#                 IMD108_Dermoscopic_Image/
#                     IMD108.bmp
#                 IMD108_lesion/
#                     IMD108_lesion.bmp
#             IMD101/
#                 IMD101_Dermoscopic_Image/
#                     IMD101.bmp
#                 IMD101_lesion/
#                     IMD101_lesion.bmp
#             IMD107/
#                 IMD107_Dermoscopic_Image/
#                     IMD107.bmp
#                 IMD107_lesion/
#                     IMD107_lesion.bmp
#             IMD103/
#                 IMD103_lesion/
#                     IMD103_lesion.bmp
#                 IMD103_Dermoscopic_Image/
#                     IMD103.bmp
#             IMD120/
#                 IMD120_lesion/
#                     IMD120_lesion.bmp
#                 IMD120_Dermoscopic_Image/
#                     IMD120.bmp
#             IMD125/
#                 IMD125_Dermoscopic_Image/
#                     IMD125.bmp
#                 IMD125_lesion/
#                     IMD125_lesion.bmp
#             IMD126/
#                 IMD126_lesion/
#                     IMD126_lesion.bmp
#                 IMD126_Dermoscopic_Image/
#                     IMD126.bmp
#             IMD112/
#                 IMD112_lesion/
#                     IMD112_lesion.bmp
#                 IMD112_Dermoscopic_Image/
#                     IMD112.bmp
#             IMD118/
#                 IMD118_Dermoscopic_Image/
#                     IMD118.bmp
#                 IMD118_lesion/
#                     IMD118_lesion.bmp
#             IMD133/
#                 IMD133_Dermoscopic_Image/
#                     IMD133.bmp
#                 IMD133_lesion/
#                     IMD133_lesion.bmp
#             IMD134/
#                 IMD134_Dermoscopic_Image/
#                     IMD134.bmp
#                 IMD134_lesion/
#                     IMD134_lesion.bmp
#             IMD137/
#                 IMD137_Dermoscopic_Image/
#                     IMD137.bmp
#                 IMD137_lesion/
#                     IMD137_lesion.bmp
#             IMD132/
#                 IMD132_lesion/
#                     IMD132_lesion.bmp
#                 IMD132_Dermoscopic_Image/
#                     IMD132.bmp
#             IMD135/
#                 IMD135_Dermoscopic_Image/
#                     IMD135.bmp
#                 IMD135_lesion/
#                     IMD135_lesion.bmp
#             IMD146/
#                 IMD146_roi/
#                     IMD146_R1_LabelStreaks.bmp
#                 IMD146_Dermoscopic_Image/
#                     IMD146.bmp
#                 IMD146_lesion/
#                     IMD146_lesion.bmp
#             IMD149/
#                 IMD149_Dermoscopic_Image/
#                     IMD149.bmp
#                 IMD149_roi/
#                     IMD149_R2_Label3.bmp
#                     IMD149_R1_Label4.bmp
#                 IMD149_lesion/
#                     IMD149_lesion.bmp
#             IMD138/
#                 IMD138_Dermoscopic_Image/
#                     IMD138.bmp
#                 IMD138_lesion/
#                     IMD138_lesion.bmp
#             IMD142/
#                 IMD142_Dermoscopic_Image/
#                     IMD142.bmp
#                 IMD142_lesion/
#                     IMD142_lesion.bmp
#             IMD147/
#                 IMD147_Dermoscopic_Image/
#                     IMD147.bmp
#                 IMD147_lesion/
#                     IMD147_lesion.bmp
#             IMD139/
#                 IMD139_Dermoscopic_Image/
#                     IMD139.bmp
#                 IMD139_lesion/
#                     IMD139_lesion.bmp
#             IMD140/
#                 IMD140_Dermoscopic_Image/
#                     IMD140.bmp
#                 IMD140_lesion/
#                     IMD140_lesion.bmp
#             IMD150/
#                 IMD150_lesion/
#                     IMD150_lesion.bmp
#                 IMD150_Dermoscopic_Image/
#                     IMD150.bmp
#             IMD143/
#                 IMD143_lesion/
#                     IMD143_lesion.bmp
#                 IMD143_Dermoscopic_Image/
#                     IMD143.bmp
#             IMD144/
#                 IMD144_lesion/
#                     IMD144_lesion.bmp
#                 IMD144_Dermoscopic_Image/
#                     IMD144.bmp
#             IMD153/
#                 IMD153_Dermoscopic_Image/
#                     IMD153.bmp
#                 IMD153_lesion/
#                     IMD153_lesion.bmp
#                 IMD153_roi/
#                     IMD153_R1_Label3.bmp
#                     IMD153_R2_Label3.bmp
#             IMD157/
#                 IMD157_Dermoscopic_Image/
#                     IMD157.bmp
#                 IMD157_lesion/
#                     IMD157_lesion.bmp
#             IMD155/
#                 IMD155_lesion/
#                     IMD155_lesion.bmp
#                 IMD155_Dermoscopic_Image/
#                     IMD155.bmp
#             IMD154/
#                 IMD154_lesion/
#                     IMD154_lesion.bmp
#                 IMD154_Dermoscopic_Image/
#                     IMD154.bmp
#                 IMD154_roi/
#                     IMD154_R1_Label3.bmp
#             IMD161/
#                 IMD161_Dermoscopic_Image/
#                     IMD161.bmp
#                 IMD161_lesion/
#                     IMD161_lesion.bmp
#             IMD160/
#                 IMD160_Dermoscopic_Image/
#                     IMD160.bmp
#                 IMD160_lesion/
#                     IMD160_lesion.bmp
#             IMD152/
#                 IMD152_lesion/
#                     IMD152_lesion.bmp
#                 IMD152_Dermoscopic_Image/
#                     IMD152.bmp
#             IMD156/
#                 IMD156_Dermoscopic_Image/
#                     IMD156.bmp
#                 IMD156_lesion/
#                     IMD156_lesion.bmp
#             IMD159/
#                 IMD159_lesion/
#                     IMD159_lesion.bmp
#                 IMD159_Dermoscopic_Image/
#                     IMD159.bmp
#             IMD162/
#                 IMD162_lesion/
#                     IMD162_lesion.bmp
#                 IMD162_Dermoscopic_Image/
#                     IMD162.bmp
#             IMD164/
#                 IMD164_Dermoscopic_Image/
#                     IMD164.bmp
#                 IMD164_roi/
#                     IMD164_R1_Label3.bmp
#                 IMD164_lesion/
#                     IMD164_lesion.bmp
#             IMD169/
#                 IMD169_lesion/
#                     IMD169_lesion.bmp
#                 IMD169_Dermoscopic_Image/
#                     IMD169.bmp
#                 IMD169_roi/
#                     IMD169_R1_Label5.bmp
#                     IMD169_R2_Label4.bmp
#                     IMD169_R3_Label4.bmp
#             IMD171/
#                 IMD171_Dermoscopic_Image/
#                     IMD171.bmp
#                 IMD171_lesion/
#                     IMD171_lesion.bmp
#             IMD175/
#                 IMD175_Dermoscopic_Image/
#                     IMD175.bmp
#                 IMD175_lesion/
#                     IMD175_lesion.bmp
#             IMD177/
#                 IMD177_lesion/
#                     IMD177_lesion.bmp
#                 IMD177_Dermoscopic_Image/
#                     IMD177.bmp
#             IMD166/
#                 IMD166_lesion/
#                     IMD166_lesion.bmp
#                 IMD166_Dermoscopic_Image/
#                     IMD166.bmp
#             IMD170/
#                 IMD170_lesion/
#                     IMD170_lesion.bmp
#                 IMD170_Dermoscopic_Image/
#                     IMD170.bmp
#             IMD173/
#                 IMD173_Dermoscopic_Image/
#                     IMD173.bmp
#                 IMD173_lesion/
#                     IMD173_lesion.bmp
#             IMD176/
#                 IMD176_lesion/
#                     IMD176_lesion.bmp
#                 IMD176_Dermoscopic_Image/
#                     IMD176.bmp
#             IMD168/
#                 IMD168_lesion/
#                     IMD168_lesion.bmp
#                 IMD168_Dermoscopic_Image/
#                     IMD168.bmp
#             IMD182/
#                 IMD182_Dermoscopic_Image/
#                     IMD182.bmp
#                 IMD182_lesion/
#                     IMD182_lesion.bmp
#             IMD198/
#                 IMD198_lesion/
#                     IMD198_lesion.bmp
#                 IMD198_Dermoscopic_Image/
#                     IMD198.bmp
#             IMD199/
#                 IMD199_lesion/
#                     IMD199_lesion.bmp
#                 IMD199_Dermoscopic_Image/
#                     IMD199.bmp
#             IMD196/
#                 IMD196_Dermoscopic_Image/
#                     IMD196.bmp
#                 IMD196_lesion/
#                     IMD196_lesion.bmp
#             IMD197/
#                 IMD197_Dermoscopic_Image/
#                     IMD197.bmp
#                 IMD197_lesion/
#                     IMD197_lesion.bmp
#             IMD207/
#                 IMD207_lesion/
#                     IMD207_lesion.bmp
#                 IMD207_Dermoscopic_Image/
#                     IMD207.bmp
#             IMD204/
#                 IMD204_Dermoscopic_Image/
#                     IMD204.bmp
#                 IMD204_lesion/
#                     IMD204_lesion.bmp
#             IMD200/
#                 IMD200_lesion/
#                     IMD200_lesion.bmp
#                 IMD200_Dermoscopic_Image/
#                     IMD200.bmp
#             IMD203/
#                 IMD203_Dermoscopic_Image/
#                     IMD203.bmp
#                 IMD203_lesion/
#                     IMD203_lesion.bmp
#             IMD206/
#                 IMD206_Dermoscopic_Image/
#                     IMD206.bmp
#                 IMD206_lesion/
#                     IMD206_lesion.bmp
#             IMD240/
#                 IMD240_lesion/
#                     IMD240_lesion.bmp
#                 IMD240_Dermoscopic_Image/
#                     IMD240.bmp
#             IMD210/
#                 IMD210_roi/
#                     IMD210_R1_Label3.bmp
#                     IMD210_R2_Label5.bmp
#                     IMD210_R4_Label4.bmp
#                     IMD210_R3_Label4.bmp
#                 IMD210_lesion/
#                     IMD210_lesion.bmp
#                 IMD210_Dermoscopic_Image/
#                     IMD210.bmp
#             IMD208/
#                 IMD208_lesion/
#                     IMD208_lesion.bmp
#                 IMD208_Dermoscopic_Image/
#                     IMD208.bmp
#             IMD243/
#                 IMD243_Dermoscopic_Image/
#                     IMD243.bmp
#                 IMD243_lesion/
#                     IMD243_lesion.bmp
#             IMD251/
#                 IMD251_Dermoscopic_Image/
#                     IMD251.bmp
#                 IMD251_lesion/
#                     IMD251_lesion.bmp
#             IMD219/
#                 IMD219_Dermoscopic_Image/
#                     IMD219.bmp
#                 IMD219_lesion/
#                     IMD219_lesion.bmp
#             IMD254/
#                 IMD254_lesion/
#                     IMD254_lesion.bmp
#                 IMD254_Dermoscopic_Image/
#                     IMD254.bmp
#             IMD211/
#                 IMD211_Dermoscopic_Image/
#                     IMD211.bmp
#                 IMD211_lesion/
#                     IMD211_lesion.bmp
#             IMD242/
#                 IMD242_Dermoscopic_Image/
#                     IMD242.bmp
#                 IMD242_lesion/
#                     IMD242_lesion.bmp
#             IMD226/
#                 IMD226_lesion/
#                     IMD226_lesion.bmp
#                 IMD226_Dermoscopic_Image/
#                     IMD226.bmp
#             IMD256/
#                 IMD256_Dermoscopic_Image/
#                     IMD256.bmp
#                 IMD256_lesion/
#                     IMD256_lesion.bmp
#             IMD278/
#                 IMD278_Dermoscopic_Image/
#                     IMD278.bmp
#                 IMD278_lesion/
#                     IMD278_lesion.bmp
#             IMD279/
#                 IMD279_Dermoscopic_Image/
#                     IMD279.bmp
#                 IMD279_lesion/
#                     IMD279_lesion.bmp
#             IMD280/
#                 IMD280_Dermoscopic_Image/
#                     IMD280.bmp
#                 IMD280_lesion/
#                     IMD280_lesion.bmp
#             IMD284/
#                 IMD284_Dermoscopic_Image/
#                     IMD284.bmp
#                 IMD284_lesion/
#                     IMD284_lesion.bmp
#             IMD304/
#                 IMD304_Dermoscopic_Image/
#                     IMD304.bmp
#                 IMD304_lesion/
#                     IMD304_lesion.bmp
#             IMD306/
#                 IMD306_Dermoscopic_Image/
#                     IMD306.bmp
#                 IMD306_lesion/
#                     IMD306_lesion.bmp
#             IMD285/
#                 IMD285_Dermoscopic_Image/
#                     IMD285.bmp
#                 IMD285_lesion/
#                     IMD285_lesion.bmp
#             IMD312/
#                 IMD312_Dermoscopic_Image/
#                     IMD312.bmp
#                 IMD312_lesion/
#                     IMD312_lesion.bmp
#             IMD305/
#                 IMD305_lesion/
#                     IMD305_lesion.bmp
#                 IMD305_Dermoscopic_Image/
#                     IMD305.bmp
#             IMD339/
#                 IMD339_Dermoscopic_Image/
#                     IMD339.bmp
#                 IMD339_lesion/
#                     IMD339_lesion.bmp
#             IMD356/
#                 IMD356_lesion/
#                     IMD356_lesion.bmp
#                 IMD356_Dermoscopic_Image/
#                     IMD356.bmp
#             IMD331/
#                 IMD331_lesion/
#                     IMD331_lesion.bmp
#                 IMD331_Dermoscopic_Image/
#                     IMD331.bmp
#             IMD328/
#                 IMD328_lesion/
#                     IMD328_lesion.bmp
#                 IMD328_Dermoscopic_Image/
#                     IMD328.bmp
#             IMD347/
#                 IMD347_Dermoscopic_Image/
#                     IMD347.bmp
#                 IMD347_lesion/
#                     IMD347_lesion.bmp
#             IMD348/
#                 IMD348_Dermoscopic_Image/
#                     IMD348.bmp
#                 IMD348_lesion/
#                     IMD348_lesion.bmp
#             IMD349/
#                 IMD349_Dermoscopic_Image/
#                     IMD349.bmp
#                 IMD349_lesion/
#                     IMD349_lesion.bmp
#             IMD360/
#                 IMD360_Dermoscopic_Image/
#                     IMD360.bmp
#                 IMD360_lesion/
#                     IMD360_lesion.bmp
#             IMD365/
#                 IMD365_Dermoscopic_Image/
#                     IMD365.bmp
#                 IMD365_lesion/
#                     IMD365_lesion.bmp
#             IMD364/
#                 IMD364_Dermoscopic_Image/
#                     IMD364.bmp
#                 IMD364_lesion/
#                     IMD364_lesion.bmp
#             IMD368/
#                 IMD368_Dermoscopic_Image/
#                     IMD368.bmp
#                 IMD368_lesion/
#                     IMD368_lesion.bmp
#             IMD370/
#                 IMD370_Dermoscopic_Image/
#                     IMD370.bmp
#                 IMD370_lesion/
#                     IMD370_lesion.bmp
#             IMD372/
#                 IMD372_Dermoscopic_Image/
#                     IMD372.bmp
#                 IMD372_lesion/
#                     IMD372_lesion.bmp
#             IMD369/
#                 IMD369_lesion/
#                     IMD369_lesion.bmp
#                 IMD369_Dermoscopic_Image/
#                     IMD369.bmp
#             IMD374/
#                 IMD374_Dermoscopic_Image/
#                     IMD374.bmp
#                 IMD374_lesion/
#                     IMD374_lesion.bmp
#             IMD375/
#                 IMD375_lesion/
#                     IMD375_lesion.bmp
#                 IMD375_Dermoscopic_Image/
#                     IMD375.bmp
#             IMD367/
#                 IMD367_lesion/
#                     IMD367_lesion.bmp
#                 IMD367_Dermoscopic_Image/
#                     IMD367.bmp
#             IMD378/
#                 IMD378_Dermoscopic_Image/
#                     IMD378.bmp
#                 IMD378_lesion/
#                     IMD378_lesion.bmp
#             IMD371/
#                 IMD371_Dermoscopic_Image/
#                     IMD371.bmp
#                 IMD371_lesion/
#                     IMD371_lesion.bmp
#             IMD376/
#                 IMD376_Dermoscopic_Image/
#                     IMD376.bmp
#                 IMD376_lesion/
#                     IMD376_lesion.bmp
#             IMD385/
#                 IMD385_lesion/
#                     IMD385_lesion.bmp
#                 IMD385_Dermoscopic_Image/
#                     IMD385.bmp
#             IMD380/
#                 IMD380_Dermoscopic_Image/
#                     IMD380.bmp
#                 IMD380_lesion/
#                     IMD380_lesion.bmp
#             IMD383/
#                 IMD383_Dermoscopic_Image/
#                     IMD383.bmp
#                 IMD383_lesion/
#                     IMD383_lesion.bmp
#             IMD379/
#                 IMD379_Dermoscopic_Image/
#                     IMD379.bmp
#                 IMD379_lesion/
#                     IMD379_lesion.bmp
#             IMD381/
#                 IMD381_lesion/
#                     IMD381_lesion.bmp
#                 IMD381_Dermoscopic_Image/
#                     IMD381.bmp
#             IMD384/
#                 IMD384_lesion/
#                     IMD384_lesion.bmp
#                 IMD384_Dermoscopic_Image/
#                     IMD384.bmp
#             IMD389/
#                 IMD389_lesion/
#                     IMD389_lesion.bmp
#                 IMD389_Dermoscopic_Image/
#                     IMD389.bmp
#             IMD388/
#                 IMD388_Dermoscopic_Image/
#                     IMD388.bmp
#                 IMD388_lesion/
#                     IMD388_lesion.bmp
#             IMD382/
#                 IMD382_Dermoscopic_Image/
#                     IMD382.bmp
#                 IMD382_lesion/
#                     IMD382_lesion.bmp
#             IMD386/
#                 IMD386_Dermoscopic_Image/
#                     IMD386.bmp
#                 IMD386_lesion/
#                     IMD386_lesion.bmp
#             IMD390/
#                 IMD390_lesion/
#                     IMD390_lesion.bmp
#                 IMD390_Dermoscopic_Image/
#                     IMD390.bmp
#             IMD392/
#                 IMD392_Dermoscopic_Image/
#                     IMD392.bmp
#                 IMD392_lesion/
#                     IMD392_lesion.bmp
#             IMD397/
#                 IMD397_Dermoscopic_Image/
#                     IMD397.bmp
#                 IMD397_lesion/
#                     IMD397_lesion.bmp
#             IMD396/
#                 IMD396_Dermoscopic_Image/
#                     IMD396.bmp
#                 IMD396_lesion/
#                     IMD396_lesion.bmp
#             IMD400/
#                 IMD400_lesion/
#                     IMD400_lesion.bmp
#                 IMD400_Dermoscopic_Image/
#                     IMD400.bmp
#             IMD399/
#                 IMD399_lesion/
#                     IMD399_lesion.bmp
#                 IMD399_Dermoscopic_Image/
#                     IMD399.bmp
#             IMD393/
#                 IMD393_lesion/
#                     IMD393_lesion.bmp
#                 IMD393_Dermoscopic_Image/
#                     IMD393.bmp
#             IMD395/
#                 IMD395_lesion/
#                     IMD395_lesion.bmp
#                 IMD395_Dermoscopic_Image/
#                     IMD395.bmp
#             IMD394/
#                 IMD394_Dermoscopic_Image/
#                     IMD394.bmp
#                 IMD394_lesion/
#                     IMD394_lesion.bmp
#             IMD398/
#                 IMD398_Dermoscopic_Image/
#                     IMD398.bmp
#                 IMD398_lesion/
#                     IMD398_lesion.bmp
#             IMD403/
#                 IMD403_Dermoscopic_Image/
#                     IMD403.bmp
#                 IMD403_lesion/
#                     IMD403_lesion.bmp
#             IMD408/
#                 IMD408_Dermoscopic_Image/
#                     IMD408.bmp
#                 IMD408_lesion/
#                     IMD408_lesion.bmp
#             IMD407/
#                 IMD407_Dermoscopic_Image/
#                     IMD407.bmp
#                 IMD407_lesion/
#                     IMD407_lesion.bmp
#             IMD405/
#                 IMD405_Dermoscopic_Image/
#                     IMD405.bmp
#                 IMD405_lesion/
#                     IMD405_lesion.bmp
#             IMD410/
#                 IMD410_Dermoscopic_Image/
#                     IMD410.bmp
#                 IMD410_lesion/
#                     IMD410_lesion.bmp
#             IMD409/
#                 IMD409_lesion/
#                     IMD409_lesion.bmp
#                 IMD409_Dermoscopic_Image/
#                     IMD409.bmp
#             IMD411/
#                 IMD411_lesion/
#                     IMD411_lesion.bmp
#                 IMD411_Dermoscopic_Image/
#                     IMD411.bmp
#             IMD404/
#                 IMD404_Dermoscopic_Image/
#                     IMD404.bmp
#                 IMD404_lesion/
#                     IMD404_lesion.bmp
#             IMD406/
#                 IMD406_lesion/
#                     IMD406_lesion.bmp
#                 IMD406_Dermoscopic_Image/
#                     IMD406.bmp
#             IMD402/
#                 IMD402_Dermoscopic_Image/
#                     IMD402.bmp
#                 IMD402_lesion/
#                     IMD402_lesion.bmp
#             IMD421/
#                 IMD421_lesion/
#                     IMD421_lesion.bmp
#                 IMD421_Dermoscopic_Image/
#                     IMD421.bmp
#             IMD420/
#                 IMD420_lesion/
#                     IMD420_lesion.bmp
#                 IMD420_Dermoscopic_Image/
#                     IMD420.bmp
#             IMD413/
#                 IMD413_Dermoscopic_Image/
#                     IMD413.bmp
#                 IMD413_lesion/
#                     IMD413_lesion.bmp
#             IMD418/
#                 IMD418_lesion/
#                     IMD418_lesion.bmp
#                 IMD418_Dermoscopic_Image/
#                     IMD418.bmp
#             IMD419/
#                 IMD419_Dermoscopic_Image/
#                     IMD419.bmp
#                 IMD419_lesion/
#                     IMD419_lesion.bmp
#             IMD424/
#                 IMD424_Dermoscopic_Image/
#                     IMD424.bmp
#                 IMD424_lesion/
#                     IMD424_lesion.bmp
#             IMD425/
#                 IMD425_Dermoscopic_Image/
#                     IMD425.bmp
#                 IMD425_lesion/
#                     IMD425_lesion.bmp
#             IMD426/
#                 IMD426_Dermoscopic_Image/
#                     IMD426.bmp
#                 IMD426_lesion/
#                     IMD426_lesion.bmp
#             IMD417/
#                 IMD417_Dermoscopic_Image/
#                     IMD417.bmp
#                 IMD417_lesion/
#                     IMD417_lesion.bmp
#             IMD423/
#                 IMD423_Dermoscopic_Image/
#                     IMD423.bmp
#                 IMD423_lesion/
#                     IMD423_lesion.bmp
#             IMD429/
#                 IMD429_Dermoscopic_Image/
#                     IMD429.bmp
#                 IMD429_lesion/
#                     IMD429_lesion.bmp
#             IMD427/
#                 IMD427_lesion/
#                     IMD427_lesion.bmp
#                 IMD427_Dermoscopic_Image/
#                     IMD427.bmp
#             IMD437/
#                 IMD437_Dermoscopic_Image/
#                     IMD437.bmp
#                 IMD437_lesion/
#                     IMD437_lesion.bmp
#             IMD432/
#                 IMD432_Dermoscopic_Image/
#                     IMD432.bmp
#                 IMD432_lesion/
#                     IMD432_lesion.bmp
#             IMD431/
#                 IMD431_Dermoscopic_Image/
#                     IMD431.bmp
#                 IMD431_lesion/
#                     IMD431_lesion.bmp
#             IMD435/
#                 IMD435_Dermoscopic_Image/
#                     IMD435.bmp
#                 IMD435_lesion/
#                     IMD435_lesion.bmp
#             IMD430/
#                 IMD430_Dermoscopic_Image/
#                     IMD430.bmp
#                 IMD430_lesion/
#                     IMD430_lesion.bmp
#             IMD436/
#                 IMD436_lesion/
#                     IMD436_lesion.bmp
#                 IMD436_Dermoscopic_Image/
#                     IMD436.bmp
#             IMD433/
#                 IMD433_Dermoscopic_Image/
#                     IMD433.bmp
#                 IMD433_lesion/
#                     IMD433_lesion.bmp
#             IMD434/
#                 IMD434_Dermoscopic_Image/
#                     IMD434.bmp
#                 IMD434_lesion/
#                     IMD434_lesion.bmp
#         generated_masks/
#             IMD009_mask.png
#             IMD004_mask.png
#             IMD002_mask.png
#             IMD015_mask.png
#             IMD010_mask.png
#             IMD006_mask.png
#             IMD003_mask.png
#             IMD013_mask.png
#             IMD008_mask.png
#             IMD014_mask.png
#             IMD018_mask.png
#             IMD020_mask.png
#             IMD019_mask.png
#             IMD017_mask.png
#             IMD025_mask.png
#             IMD023_mask.png
#             IMD022_mask.png
#             IMD021_mask.png
#             IMD024_mask.png
#             IMD016_mask.png
#             IMD027_mask.png
#             IMD030_mask.png
#             IMD032_mask.png
#             IMD039_mask.png
#             IMD038_mask.png
#             IMD031_mask.png
#             IMD037_mask.png
#             IMD036_mask.png
#             IMD033_mask.png
#             IMD035_mask.png
#             IMD041_mask.png
#             IMD040_mask.png
#             IMD045_mask.png
#             IMD047_mask.png
#             IMD043_mask.png
#             IMD044_mask.png
#             IMD049_mask.png
#             IMD048_mask.png
#             IMD042_mask.png
#             IMD050_mask.png
#             IMD057_mask.png
#             IMD078_mask.png
#             IMD063_mask.png
#             IMD058_mask.png
#             IMD076_mask.png
#             IMD065_mask.png
#             IMD061_mask.png
#             IMD064_mask.png
#             IMD075_mask.png
#             IMD080_mask.png
#             IMD085_mask.png
#             IMD090_mask.png
#             IMD105_mask.png
#             IMD091_mask.png
#             IMD088_mask.png
#             IMD092_mask.png
#             IMD108_mask.png
#             IMD101_mask.png
#             IMD107_mask.png
#             IMD103_mask.png
#             IMD120_mask.png
#             IMD125_mask.png
#             IMD126_mask.png
#             IMD112_mask.png
#             IMD118_mask.png
#             IMD133_mask.png
#             IMD134_mask.png
#             IMD137_mask.png
#             IMD132_mask.png
#             IMD135_mask.png
#             IMD146_mask.png
#             IMD149_mask.png
#             IMD138_mask.png
#             IMD142_mask.png
#             IMD147_mask.png
#             IMD139_mask.png
#             IMD140_mask.png
#             IMD150_mask.png
#             IMD143_mask.png
#             IMD144_mask.png
#             IMD153_mask.png
#             IMD157_mask.png
#             IMD155_mask.png
#             IMD154_mask.png
#             IMD161_mask.png
#             IMD160_mask.png
#             IMD152_mask.png
#             IMD156_mask.png
#             IMD159_mask.png
#             IMD162_mask.png
#             IMD164_mask.png
#             IMD169_mask.png
#             IMD171_mask.png
#             IMD175_mask.png
#             IMD177_mask.png
#             IMD166_mask.png
#             IMD170_mask.png
#             IMD173_mask.png
#             IMD176_mask.png
#             IMD168_mask.png
#             IMD182_mask.png
#             IMD198_mask.png
#             IMD199_mask.png
#             IMD196_mask.png
#             IMD197_mask.png
#             IMD207_mask.png
#             IMD204_mask.png
#             IMD200_mask.png
#             IMD203_mask.png
#             IMD206_mask.png
#             IMD240_mask.png
#             IMD210_mask.png
#             IMD208_mask.png
#             IMD243_mask.png
#             IMD251_mask.png
#             IMD219_mask.png
#             IMD254_mask.png
#             IMD211_mask.png
#             IMD242_mask.png
#             IMD226_mask.png
#             IMD256_mask.png
#             IMD278_mask.png
#             IMD279_mask.png
#             IMD280_mask.png
#             IMD284_mask.png
#             IMD304_mask.png
#             IMD306_mask.png
#             IMD285_mask.png
#             IMD312_mask.png
#             IMD305_mask.png
#             IMD339_mask.png
#             IMD356_mask.png
#             IMD331_mask.png
#             IMD328_mask.png
#             IMD347_mask.png
#             IMD348_mask.png
#             IMD349_mask.png
#             IMD360_mask.png
#             IMD365_mask.png
#             IMD364_mask.png
#             IMD368_mask.png
#             IMD370_mask.png
#             IMD372_mask.png
#             IMD369_mask.png
#             IMD374_mask.png
#             IMD375_mask.png
#             IMD367_mask.png
#             IMD378_mask.png
#             IMD371_mask.png
#             IMD376_mask.png
#             IMD385_mask.png
#             IMD380_mask.png
#             IMD383_mask.png
#             IMD379_mask.png
#             IMD381_mask.png
#             IMD384_mask.png
#             IMD389_mask.png
#             IMD388_mask.png
#             IMD382_mask.png
#             IMD386_mask.png
#             IMD390_mask.png
#             IMD392_mask.png
#             IMD397_mask.png
#             IMD396_mask.png
#             IMD400_mask.png
#             IMD399_mask.png
#             IMD393_mask.png
#             IMD395_mask.png
#             IMD394_mask.png
#             IMD398_mask.png
#             IMD403_mask.png
#             IMD408_mask.png
#             IMD407_mask.png
#             IMD405_mask.png
#             IMD410_mask.png
#             IMD409_mask.png
#             IMD411_mask.png
#             IMD404_mask.png
#             IMD406_mask.png
#             IMD402_mask.png
#             IMD421_mask.png
#             IMD420_mask.png
#             IMD413_mask.png
#             IMD418_mask.png
#             IMD419_mask.png
#             IMD424_mask.png
#             IMD425_mask.png
#             IMD426_mask.png
#             IMD417_mask.png
#             IMD423_mask.png
#             IMD429_mask.png
#             IMD427_mask.png
#             IMD437_mask.png
#             IMD432_mask.png
#             IMD431_mask.png
#             IMD435_mask.png
#             IMD430_mask.png
#             IMD436_mask.png
#             IMD433_mask.png
#             IMD434_mask.png

# %% [markdown]
# 🔹 STEP 6: Feature Extraction (Masked Area)

# %%
def extract_features(img, mask):
    features = []
    _, mask_bin = cv2.threshold(mask, 127, 255, cv2.THRESH_BINARY)

    for i in range(3):  # BGR
        pixels = img[:,:,i][mask_bin > 0]
        if pixels.size == 0:
            features.extend([0,0])
        else:
            features.extend([pixels.mean(), pixels.std()])
    return features  # 6 features

# %% [markdown]
# 🔹 STEP 7: Build Dataset (X, y)

# %%
X, y = [], []

for folder in os.listdir(BASE_PATH):
    if folder not in label_dict:
        continue

    mask_path = os.path.join(MASK_SAVE_PATH, f"{folder}_mask.png")
    img_folder = os.path.join(BASE_PATH, folder, f"{folder}_Dermoscopic_Image")

    if not os.path.exists(mask_path) or not os.path.exists(img_folder):
        continue

    img = cv2.imread(os.path.join(img_folder, os.listdir(img_folder)[0]))
    mask = cv2.imread(mask_path, 0)

    if img is None or mask is None:
        continue

    X.append(extract_features(img, mask))
    y.append(label_dict[folder])

X = np.array(X)
y = np.array(y)

print("Feature matrix:", X.shape)
print("Labels:", y.shape)
# Out:
# Feature matrix: (200, 6)
# Labels: (200,)

# %% [markdown]
# Train/Test Split Example

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# %%
clf = RandomForestClassifier(
    n_estimators=80,
    max_depth=8,
    random_state=42
)

clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %% [markdown]
# Classifier:

# %%
acc = accuracy_score(y_test, y_pred)
f1  = f1_score(y_test, y_pred)

print("Accuracy:", acc)
print("F1 Score:", f1)
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.86
# F1 Score: 0.2222222222222222
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.92        43
#            1       0.50      0.14      0.22         7
#
#     accuracy                           0.86        50
#    macro avg       0.69      0.56      0.57        50
# weighted avg       0.82      0.86      0.82        50
